# %%
import pandas as pd
import pathlib

# %%
TEST_PICKLE = str(list(pathlib.Path('.').glob('*.p'))[0])

# %%
object = pd.read_pickle(TEST_PICKLE)

# %%
object
# Out:
#                                                     titles  \
# 1               GRADCORPS: Junior Analyst - Infrastructure
# 8                                      Junior Data Analyst
# 3                                     Junior Data Engineer
# 10                             Junior Supply Chain Analyst
# 11  Junior Data Integration Developer - Développeur junior
# 0                         Junior Data Scientist, Analytics
# 6                        Junior Machine Learning Scientist
# 12                          Junior Business Analyst intern
# 2                                      Junior Data Analyst
# 4                     Junior Business Intelligence Analyst
# 13                     Financial Analyst (Program), Junior
# 5                                     Junior Power Analyst
# 7                         Junior Business Analyst – CPM/BI
# 9                           Junior Bookkeeper / data entry
# 14                                      Jr. Data Scientist
#
# ...
