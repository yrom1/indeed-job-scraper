# %%
import pandas as pd
import pathlib

# %%
TEST_PICKLE = str(list(pathlib.Path('.').glob('*.p'))[0])

# %%
object = pd.read_pickle(TEST_PICKLE)

# %%
object
# Out:
#                                                 titles  \
# 0                     Junior Data Scientist, Analytics
# 138  Business Analyst I, Wireless Fulfillment (Logi...
# 140                          Benefits Analyst (Junior)
# 141  Toronto - Junior Technical Business Analyst/ J...
# 142               Junior Financial Analyst, Consulting
# ..                                                 ...
# 67            Analyste PMO junior - Junior PMO Analyst
# 71                             Junior Business Analyst
# 75   Junior Consultant SAP Analytics - college grad...
# 76                       Junior Sales Data Coordinator
# 217                     Financial Analyst I (Contract)
#
#                                   companyNames  \
# 0                                         FORM
# 138                                      TELUS
# 140             JRP Employee Benefit Solutions
# 141                                  FDM Group
# 142                                        BDO
# ...
